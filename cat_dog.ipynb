# %% [markdown]
# <a href="https://colab.research.google.com/github/Ikejapa/ikejapa.github.io/blob/main/cat_dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# ...

# %%
# !pip install keras == 2.2.5
# !pip install tensorflow==1.14.0
# !pip install h5py==2.10.0
# Out:
# ERROR: Invalid requirement: '=='
# ...

# %%
# from icrawler.builtin import GoogleImageCrawler
# 猫の画像を100枚取得
# crawler = GoogleImageCrawler(storage={"root_dir": "cats"})
# crawler.crawl(keyword="猫", max_num=100)
from icrawler.builtin import BingImageCrawler

# 猫の画像を100枚取得
crawler = BingImageCrawler(storage={"root_dir": "cat"})
crawler.crawl(keyword="猫", max_num=100)
# Out:
# 2022-05-22 06:26:10,434 - INFO - icrawler.crawler - start crawling...
# 2022-05-22 06:26:10,436 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2022-05-22 06:26:10,438 - INFO - feeder - thread feeder-001 exit
# 2022-05-22 06:26:10,443 - INFO - icrawler.crawler - starting 1 parser threads...
# 2022-05-22 06:26:10,446 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2022-05-22 06:26:10,667 - INFO - downloader - image #48	http://www.kaleno.net/wp-content/uploads/2010/01/R0010327.jpg
# 2022-05-22 06:26:10,777 - INFO - parser - parsing result page https://www.bing.com/images/async?q=猫&first=0
# 2022-05-22 06:26:10,800 - INFO - downloader - skip downloading file 000001.jpg
# 2022-05-22 06:26:10,802 - INFO - downloader - skip downloading file 000002.jpg
# 2022-05-22 06:26:10,804 - INFO - downloader - skip downloading file 000003.jpg
# 2022-05-22 06:26:10,807 - INFO - downloader - skip downloading file 000004.jpg
# ...

# %%
from icrawler.builtin import BingImageCrawler
crawler = BingImageCrawler(storage={"root_dir": "dog"})
crawler.crawl(keyword="犬", max_num=100)
# Out:
# 2022-05-22 06:30:16,851 - INFO - icrawler.crawler - start crawling...
# 2022-05-22 06:30:16,854 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2022-05-22 06:30:16,855 - INFO - feeder - thread feeder-001 exit
# 2022-05-22 06:30:16,855 - INFO - icrawler.crawler - starting 1 parser threads...
# 2022-05-22 06:30:16,860 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2022-05-22 06:30:17,167 - INFO - parser - parsing result page https://www.bing.com/images/async?q=犬&first=0
# 2022-05-22 06:30:18,418 - INFO - downloader - image #1	https://stat.ameba.jp/user_images/20201020/08/smile-112/d5/28/j/o1024102314837634910.jpg
# 2022-05-22 06:30:19,759 - INFO - downloader - image #2	https://stat.ameba.jp/user_images/20200920/22/smile-112/5a/52/j/o1024102314822510144.jpg
# 2022-05-22 06:30:19,927 - INFO - downloader - image #3	https://1.bp.blogspot.com/-LmmkeFy607Y/WrD1GfzHAKI/AAAAAAAAF_c/hDdmR33XaGg01i9R6HocUMlAcSljwv5dQCLcBGAs/s1600/Rigeru1.jpg
# ...

# %%
from IPython.display import Image,display_jpeg
display_jpeg(Image("./cat/000001.jpg"))
